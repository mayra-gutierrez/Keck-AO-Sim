# %%
import time
import sys
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter
import hcipy
from hcipy import *

from astropy.io import fits
print(fits)

import os, sys
os.chdir("/Users/mayragutierrez/keckAOSim/keckSim")
sys.path.insert(0, os.path.join(os.getcwd(), "simulations_codes"))
os.environ["OOPAO_PATH"]="/Users/mayragutierrez/OOPAO"
sys.path.insert(0, "/Users/mayragutierrez/OOPAO")
#sys.path.insert(0, os.getcwd())

from OOPAO.calibration.getFittingError import *
from OOPAO.calibration.CalibrationVault import CalibrationVault
from OOPAO.OPD_map import OPD_map
from OOPAO.calibration.compute_KL_modal_basis import compute_KL_basis
from scipy.ndimage import center_of_mass
from scipy.optimize import curve_fit

import importlib
from KAO_parameter_file import initializeParameterFile
from initialize_AO import initialize_AO_hardware
import close_loop_coro
from close_loop_coro import close_loop
importlib.reload(close_loop_coro)
# Out:
# <module 'astropy.io.fits' from '/opt/anaconda3/envs/oopao/lib/python3.9/site-packages/astropy/io/fits/__init__.py'>
#
#
# ==================================
#      °          *      *
#  ▄██▄   ▄██▄  ▄███▄   ▄██▄ * ▄██▄
# ██* ██ ██  ██ ██  ██ ██  ██ ██  ██
# ██  ██ ██° ██ ██  ██ ██* ██ ██  ██
# ██  ██ ██  ██ ████▀  ██▄▄██ ██  ██
# ██* ██ ██  ██ ██     ██▀▀██ ██  ██
# ██  ██ ██  ██ ██ *   ██  ██ ██* ██
#  ▀██▀   ▀██▀  ██   ° ██  ██  ▀██▀
#       *         *
# ==================================
# <module 'close_loop_coro' from '/Users/mayragutierrez/keckAOSim/keckSim/simulations_codes/close_loop_coro.py'>

# %%
param = initializeParameterFile()
KAO = initialize_AO_hardware(param)

M1_opd = KAO.opd_M1.OPD #optical path difference on primary mirror
ncpa = KAO.opd_ncpa.OPD #non-common path abberations
jitter_x = KAO.jitter.x #tip-tilt jitter along x-axis
# Out:
# OOPAO Warning:
# User-defined pupil, the central obstruction will not be taken into account...
#
# ------------ Telescope -------------
# Diameter [m]             |  10.93
# Resolution [px]          |   480
# Pixel size [m]           |   0.02
# Surface [m²]             |  71.63
# Central obstruction [%]  |    0
# Pixels in pupil          |  138152
# Field of view [arcsec]   |   0.00
# ------------------------------------
#
#
# ------------- Source --------------
# Source                   |   NGS
# Wavelength [m]           | 6.4e-07
# Zenith [arcsec]          |  0.00
# Azimuth [°]              |  0.00
# Altitude [m]             |   inf
# Magnitude                |  5.00
# Flux [photon/m²/s]       | 1.1e+08
# Coordinates [arcsec,deg] | [0,0]
# -----------------------------------
#
#
# ------------- Source --------------
# Source                   |   NGS
# Wavelength [m]           | 2.2e-06
# Zenith [arcsec]          |  0.00
# Azimuth [°]              |  0.00
# Altitude [m]             |   inf
# Magnitude                |  5.00
# Flux [photon/m²/s]       | 1.9e+07
# Coordinates [arcsec,deg] | [0,0]
# -----------------------------------
#
# Creation of layer1/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.0404360294342041 s
# ZZt.. : 15.582726955413818 s
# ZXt.. : 1.3542687892913818 s
# XXt.. : 0.6636910438537598 s
# Done!
# Creation of layer2/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.08573698997497559 s
# ZZt.. : 9.5367431640625e-07 s
# ZXt.. : 9.059906005859375e-06 s
# XXt.. : 2.86102294921875e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Creation of layer3/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.05638718605041504 s
# ZZt.. : 9.5367431640625e-07 s
# ZXt.. : 6.9141387939453125e-06 s
# XXt.. : 3.0994415283203125e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Creation of layer4/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.09935998916625977 s
# ZZt.. : 9.5367431640625e-07 s
# ZXt.. : 8.106231689453125e-06 s
# XXt.. : 1.9073486328125e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Creation of layer5/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.054850101470947266 s
# ZZt.. : 5.9604644775390625e-06 s
# ZXt.. : 7.867813110351562e-06 s
# XXt.. : 9.298324584960938e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Creation of layer6/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.05521988868713379 s
# ZZt.. : 0.0 s
# ZXt.. : 5.0067901611328125e-06 s
# XXt.. : 4.76837158203125e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Creation of layer7/7 ...
# -> Computing the initial phase screen...
# initial phase screen : 0.07432675361633301 s
# ZZt.. : 9.5367431640625e-07 s
# ZXt.. : 6.198883056640625e-06 s
# XXt.. : 3.0994415283203125e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# Updating the Atmosphere covariance matrices...
#
# ------------------------ Atmosphere -------------------------
#  Layer | Direction | Speed | Altitude | Frac Cn² | Diameter |
#        |    [°]    | [m/s] |   [m]    |   [%]    |   [m]    |
#    1   |     0     |  5.8  |  1e+02   |    52    |  11.021  |
#    2   |     2     |  5.9  |  5e+02   |    12    |  11.021  |
#    3   |     1     |  6.1  |  1e+03   |    6     |  11.021  |
#    4   |     5     |  6.5  |  2e+03   |    6     |  11.021  |
#    5   |     8     |  9.0  |  4e+03   |    10    |  11.021  |
#    6   |     0     | 25.9  |  8e+03   |    8     |  11.021  |
#    7   |     3     | 17.5  |  2e+04   |    5     |  11.021  |
# =============================================================
# r0 @ 500 nm [m] |   0.13
# L0 [m]          |   80.0
# Tau0 [s]        |  0.0048
# V0 [m/s]        |   8.47
# Frequency [Hz]  |  500.0
# -------------------------------------------------------------
#
# No coordinates loaded.. taking the cartesian geometry as a default
# Generating a Deformable Mirror:
# Computing the 2D zonal modes...
#
# -------- Deformable mirror --------
# Controlled Actuators     |   357
# M4                       |  False
# Pitch [m]                |  0.55
# Mechnical coupling [%]   |   15
# == Misregistration ================
# Rotation [°]             |  0.000
# Shift X [m]              |0.000e+00
# Shift Y [m]              |0.000e+00
# Anamorphosis angle [°]   |  0.000
# Tangential scaling [%]   |  0.000
# Radial scaling [%]       |  0.000
# -----------------------------------
#
# No coordinates loaded.. taking the cartesian geometry as a default
# Generating a Deformable Mirror:
# Loading the 2D zonal modes...
# Done!
#
# -------- Deformable mirror --------
# Controlled Actuators     |   298
# M4                       |  False
# Pitch [m]                |  0.55
# Mechnical coupling [%]   |   15
# == Misregistration ================
# Rotation [°]             |  0.000
# Shift X [m]              |0.000e+00
# Shift Y [m]              |0.000e+00
# Anamorphosis angle [°]   |  0.000
# Tangential scaling [%]   |  0.000
# Radial scaling [%]       |  0.000
# -----------------------------------
#
# No coordinates loaded.. taking the cartesian geometry as a default
# Generating a Deformable Mirror:
# Loading the 2D zonal modes...
# Done!
#
# -------- Deformable mirror --------
# Controlled Actuators     |    2
# M4                       |  False
# Pitch [m]                |  5.46
# Mechnical coupling [%]   |   15
# == Misregistration ================
# Rotation [°]             |  0.000
# Shift X [m]              |0.000e+00
# Shift Y [m]              |0.000e+00
# Anamorphosis angle [°]   |  0.000
# Tangential scaling [%]   |  0.000
# Radial scaling [%]       |  0.000
# -----------------------------------
#
# User input pixel scale - The shannon_sampling input value is ignored
# The effective pixel-scale is: 0.8454473523930511 arcsec
# -------------Detector--------------
# Sensor type              |   CCD
# Resolution [px]          |   80
# Gain                     |    1
# Quantum efficiency [%]   |   100
# Binning                  |   1x1
# Dark current [e-/px/s]   |  0.00
# Photon noise             |  False
# Bkg noise [e-]           |  False
# Readout noise [e-/px]    |   0.0
# -----------------------------------
#
# Selecting valid subapertures based on flux considerations..
# Acquiring reference slopes..
# Done!
# Setting slopes units..
# Done!
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% SHACK HARTMANN WFS %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     Subapertures            20
#   Subaperture Size         0.55              [m]
#      Pixel FoV             0.85            [arcsec]
#    Subapertue FoV          3.38            [arcsec]
#  Valid Subaperture         252
#    Binning Factor           1
#    Spot Sampling    0.2857142857142857    [pix/FWHM]
#    Geometric WFS          False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# -------------Detector--------------
# Sensor type              |   CCD
# Resolution [px]          |  1024
# Exposure time [ms]       |  20.00
# Quantization [bits]      |   14
# Gain                     |    1
# Quantum efficiency [%]   |   92
# Binning                  |   1x1
# Dark current [e-/px/s]   |  0.00
# Photon noise             |  True
# Bkg noise [e-]           |  False
# Readout noise [e-/px]    |   0.5
# -----------------------------------
#
# No KL basis found at /home/mcisse/keckAOSim/keckSim/data/M2C_KL_telescope_res480_DM_nact_21.npz, computing new one...
# TIME ELAPSED: 0 sec. COMPLETED: 1 %
# TIME ELAPSED: 1 sec. COMPLETED: 3 %
# TIME ELAPSED: 1 sec. COMPLETED: 5 %
# TIME ELAPSED: 2 sec. COMPLETED: 6 %
# TIME ELAPSED: 2 sec. COMPLETED: 8 %
# TIME ELAPSED: 3 sec. COMPLETED: 10 %
# TIME ELAPSED: 3 sec. COMPLETED: 12 %
# TIME ELAPSED: 3 sec. COMPLETED: 13 %
# TIME ELAPSED: 4 sec. COMPLETED: 15 %
# TIME ELAPSED: 4 sec. COMPLETED: 17 %
# TIME ELAPSED: 5 sec. COMPLETED: 17 %
# TIME ELAPSED: 5 sec. COMPLETED: 19 %
# TIME ELAPSED: 6 sec. COMPLETED: 21 %
# TIME ELAPSED: 6 sec. COMPLETED: 22 %
# TIME ELAPSED: 6 sec. COMPLETED: 24 %
# TIME ELAPSED: 7 sec. COMPLETED: 26 %
# TIME ELAPSED: 7 sec. COMPLETED: 28 %
# TIME ELAPSED: 8 sec. COMPLETED: 29 %
# TIME ELAPSED: 8 sec. COMPLETED: 31 %
# TIME ELAPSED: 9 sec. COMPLETED: 33 %
# TIME ELAPSED: 9 sec. COMPLETED: 33 %
# TIME ELAPSED: 10 sec. COMPLETED: 35 %
# TIME ELAPSED: 10 sec. COMPLETED: 37 %
# TIME ELAPSED: 11 sec. COMPLETED: 38 %
# TIME ELAPSED: 11 sec. COMPLETED: 40 %
# TIME ELAPSED: 12 sec. COMPLETED: 42 %
# TIME ELAPSED: 12 sec. COMPLETED: 44 %
# TIME ELAPSED: 12 sec. COMPLETED: 45 %
# TIME ELAPSED: 13 sec. COMPLETED: 47 %
# TIME ELAPSED: 13 sec. COMPLETED: 48 %
# TIME ELAPSED: 14 sec. COMPLETED: 49 %
# TIME ELAPSED: 14 sec. COMPLETED: 51 %
# TIME ELAPSED: 15 sec. COMPLETED: 53 %
# TIME ELAPSED: 15 sec. COMPLETED: 55 %
# TIME ELAPSED: 16 sec. COMPLETED: 56 %
# TIME ELAPSED: 16 sec. COMPLETED: 58 %
# TIME ELAPSED: 17 sec. COMPLETED: 60 %
# TIME ELAPSED: 17 sec. COMPLETED: 60 %
# TIME ELAPSED: 18 sec. COMPLETED: 62 %
# TIME ELAPSED: 18 sec. COMPLETED: 64 %
# TIME ELAPSED: 19 sec. COMPLETED: 65 %
# TIME ELAPSED: 19 sec. COMPLETED: 67 %
# TIME ELAPSED: 20 sec. COMPLETED: 69 %
# TIME ELAPSED: 20 sec. COMPLETED: 71 %
# TIME ELAPSED: 20 sec. COMPLETED: 71 %
# TIME ELAPSED: 21 sec. COMPLETED: 73 %
# TIME ELAPSED: 21 sec. COMPLETED: 75 %
# TIME ELAPSED: 22 sec. COMPLETED: 76 %
# TIME ELAPSED: 22 sec. COMPLETED: 78 %
# TIME ELAPSED: 23 sec. COMPLETED: 80 %
# TIME ELAPSED: 23 sec. COMPLETED: 80 %
# TIME ELAPSED: 23 sec. COMPLETED: 82 %
# TIME ELAPSED: 24 sec. COMPLETED: 84 %
# TIME ELAPSED: 24 sec. COMPLETED: 85 %
# TIME ELAPSED: 25 sec. COMPLETED: 87 %
# TIME ELAPSED: 25 sec. COMPLETED: 88 %
# TIME ELAPSED: 26 sec. COMPLETED: 89 %
# TIME ELAPSED: 26 sec. COMPLETED: 91 %
# TIME ELAPSED: 27 sec. COMPLETED: 93 %
# TIME ELAPSED: 27 sec. COMPLETED: 93 %
# TIME ELAPSED: 27 sec. COMPLETED: 95 %
# TIME ELAPSED: 28 sec. COMPLETED: 97 %
# TIME ELAPSED: 28 sec. COMPLETED: 97 %
# TIME ELAPSED: 28 sec. COMPLETED: 99 %
# TIME ELAPSED: 29 sec. COMPLETED: 99 %
# TIME ELAPSED: 29 sec. COMPLETED: 100 %
# NMAX =  297
# RMS opd error = [[1.36705663e-08 1.57356345e-08 1.62243840e-08]]
# RMS Positions = [[3.50921452e-08 6.74075643e-07 6.71412257e-07]]
# MAX Positions = [[7.53864034e-07 1.39846029e-06 1.49506471e-06]]
# WARNING: Number of modes requested too high, taking the maximum value possible!
# KL WITH DOUBLE DIAGONALISATION: COVARIANCE ERROR =  6.823147585816021e-14
# Truncate modal basis
# Re-initializing WFS...
# Acquiring reference slopes..
# Done!
# Setting slopes units..
# Done!
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% SHACK HARTMANN WFS %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     Subapertures            20
#   Subaperture Size         0.55              [m]
#      Pixel FoV             0.85            [arcsec]
#    Subapertue FoV          3.38            [arcsec]
#  Valid Subaperture         252
#    Binning Factor           1
#    Spot Sampling    0.2857142857142857    [pix/FWHM]
#    Geometric WFS          False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Keck rec build!
# No segments tilts or pistons
# False
# M1 flat!
# Everything has been loaded and the calibration are done!

# %%
plt.figure(), plt.imshow(KAO.opd_M1.OPD), plt.colorbar(), plt.title('M1 OPD'), plt.show()
plt.figure(), plt.imshow(KAO.opd_ncpa.OPD), plt.colorbar(), plt.title('NCPA OPD'), plt.show()
plt.figure(), plt.plot(jitter_x), plt.title('Jitter amplitude'), plt.show()

plt.figure()
plt.imshow(np.reshape(np.sum(KAO.dm.modes**5,axis=1),[KAO.tel.resolution,KAO.tel.resolution]).T +
            KAO.tel.pupil,extent=[-KAO.tel.D/2,KAO.tel.D/2,-KAO.tel.D/2,KAO.tel.D/2])
plt.plot(KAO.dm.coordinates[:,0],KAO.dm.coordinates[:,1],'rx')
plt.xlabel('[m]')
plt.ylabel('[m]')
plt.title('DM Actuator Coordinates keck')
plt.colorbar()
plt.show()

plt.figure(), plt.plot(KAO.calib_zonal.eigenValues,'rx'), plt.ylabel('eigenValues zonal'), plt.show(block=False)
plt.figure(), plt.imshow(KAO.calib_zonal.D), plt.colorbar(), plt.title('Zonal Imat'), plt.show(block=False)

KAO.tel+KAO.atm
KAO.ngs * KAO.tel * KAO.wfs
plt.figure(), plt.imshow(KAO.wfs.signal_2D), plt.colorbar(), plt.title('Slopes'), plt.show(block=False)

print(f'Incoming photon on WFS {np.sum(KAO.wfs.signal)}')
# Out:
# Telescope and Atmosphere combined!
# Incoming photon on WFS 229.89906789360563

# %%
# %% -----------------------     plot PSF  ----------------------------------

# diff at the science wavelength
LD = KAO.science.wavelength/KAO.tel.D * 206265 * 1000 # in mas

PSF_diff = KAO.PSF_diff
PSF_ncpa = KAO.PSF_ncpa
size_psf = PSF_diff.shape[0]//2
wind = 100
plt.figure(), plt.imshow(PSF_diff[size_psf-wind:size_psf+wind,size_psf-wind:size_psf+wind]**0.2), plt.colorbar(), plt.title('Diffraction limited PSF'), plt.show()
plt.figure(), plt.imshow(PSF_ncpa[size_psf-wind:size_psf+wind,size_psf-wind:size_psf+wind]**0.2), plt.colorbar(), plt.title('NCPA PSF'), plt.show()
# Out:
# /var/folders/g2/4by_wvp50hq5wxb7sgwwwmxm0000gn/T/ipykernel_17744/3560698473.py:10: RuntimeWarning: invalid value encountered in power
#   plt.figure(), plt.imshow(PSF_diff[size_psf-wind:size_psf+wind,size_psf-wind:size_psf+wind]**0.2), plt.colorbar(), plt.title('Diffraction limited PSF'), plt.show()
# /var/folders/g2/4by_wvp50hq5wxb7sgwwwmxm0000gn/T/ipykernel_17744/3560698473.py:11: RuntimeWarning: invalid value encountered in power
#   plt.figure(), plt.imshow(PSF_ncpa[size_psf-wind:size_psf+wind,size_psf-wind:size_psf+wind]**0.2), plt.colorbar(), plt.title('NCPA PSF'), plt.show()
# (<Figure size 640x480 with 2 Axes>,
#  <matplotlib.image.AxesImage at 0x31ed6c0d0>,
#  <matplotlib.colorbar.Colorbar at 0x31ed39250>,
#  Text(0.5, 1.0, 'NCPA PSF'),
#  None)

# %%
KAO.param['print_display'] =True
KAO.param['nLoop']=100

AO_output_modal,L_psf,L_coro = close_loop(KAO)
SR_mode = AO_output_modal['SR']
res_mode = AO_output_modal['residual']
PSF_LE_mode = AO_output_modal['PSF_LE']
PSF_coro_mode = AO_output_modal['PSF_coro']
# Out:
# Re-initializing WFS...
# Acquiring reference slopes..
# Done!
# Setting slopes units..
# Done!
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% SHACK HARTMANN WFS %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     Subapertures            20
#   Subaperture Size         0.55              [m]
#      Pixel FoV             0.85            [arcsec]
#    Subapertue FoV          3.38            [arcsec]
#  Valid Subaperture         252
#    Binning Factor           1
#    Spot Sampling    0.2857142857142857    [pix/FWHM]
#    Geometric WFS          False
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Flux updated, magnitude is  5 and flux is 1.09e+08
# Flux updated, magnitude is  5 and flux is 1.90e+07
# Telescope and Atmosphere combined!
# Loop0/1000 Turbulence: 931.1675919784851 -- Residual:931.1675919784851 -- Fitting:127.64935566884715 -- SR:0.0007395779579250912
#
# Loop1/1000 Turbulence: 931.0974237051537 -- Residual:931.0974237051537 -- Fitting:127.89775984484538 -- SR:0.0007403819420260077
#
# Loop2/1000 Turbulence: 930.9954828357979 -- Residual:808.1575033013812 -- Fitting:127.62926999974023 -- SR:0.004381043005806275
#
# Loop3/1000 Turbulence: 930.984694429156 -- Residual:694.7211527997105 -- Fitting:127.7966064162549 -- SR:0.018079550786848007
#
# Loop4/1000 Turbulence: 930.8874029692854 -- Residual:601.4573355142716 -- Fitting:127.53830281023095 -- SR:0.04939819621621889
#
# Loop5/1000 Turbulence: 930.8406304737479 -- Residual:527.8127593822123 -- Fitting:127.76878585692822 -- SR:0.09863248521992475
#
# Loop6/1000 Turbulence: 930.7239876458826 -- Residual:470.2789000663037 -- Fitting:127.70176715060194 -- SR:0.15899346620249385
#
# Loop7/1000 Turbulence: 930.5873492529288 -- Residual:426.3572101584213 -- Fitting:127.96638752369743 -- SR:0.22059087724948792
#
# Loop8/1000 Turbulence: 930.3843049293555 -- Residual:390.7321780465292 -- Fitting:127.9466860152039 -- SR:0.2809959506994268
#
# Loop9/1000 Turbulence: 930.2425115654935 -- Residual:360.3939751038919 -- Fitting:128.16380173796173 -- SR:0.3396153167832304
#
# Loop10/1000 Turbulence: 930.0769498598243 -- Residual:333.5304189112823 -- Fitting:128.04117180329735 -- SR:0.3965530050599456
#
# Loop11/1000 Turbulence: 929.9254032271144 -- Residual:310.35989879778214 -- Fitting:127.97376362556855 -- SR:0.44892625197655184
#
# Loop12/1000 Turbulence: 929.7665709739512 -- Residual:290.3463140220486 -- Fitting:127.52496105779075 -- SR:0.4961210822756303
#
# Loop13/1000 Turbulence: 929.6868430284326 -- Residual:273.5741923647393 -- Fitting:127.11556659953897 -- SR:0.5367118734427946
#
# Loop14/1000 Turbulence: 929.6132463369364 -- Residual:259.09714318032195 -- Fitting:126.44760502185063 -- SR:0.5722523662371521
#
# Loop15/1000 Turbulence: 929.5771194574875 -- Residual:248.3207929299383 -- Fitting:126.03775444695445 -- SR:0.5988706786368634
#
# Loop16/1000 Turbulence: 929.5344097376319 -- Residual:240.0097104144641 -- Fitting:125.6947060915782 -- SR:0.6194247630921396
#
# Loop17/1000 Turbulence: 929.5835473542618 -- Residual:232.93168578346774 -- Fitting:125.70245237999163 -- SR:0.6369075707977955
#
# Loop18/1000 Turbulence: 929.6660155280712 -- Residual:226.1703893218443 -- Fitting:125.82582355582174 -- SR:0.6535599963793416
#
# Loop19/1000 Turbulence: 929.8160188238885 -- Residual:219.80601320006892 -- Fitting:126.19970963395767 -- SR:0.6691674919603068
#
# Loop20/1000 Turbulence: 930.0582676274569 -- Residual:213.51390620954285 -- Fitting:126.7394029361205 -- SR:0.684510724751183
#
# Loop21/1000 Turbulence: 930.3701373462808 -- Residual:207.0657422297575 -- Fitting:127.26234214778638 -- SR:0.7001211789795848
#
# Loop22/1000 Turbulence: 930.7505708867046 -- Residual:201.0849360334616 -- Fitting:127.59066966708703 -- SR:0.7144765219141928
#
# Loop23/1000 Turbulence: 931.2174651718511 -- Residual:195.77701224686496 -- Fitting:127.7384199708252 -- SR:0.7271007913737914
#
# Loop24/1000 Turbulence: 931.7199389898226 -- Residual:191.16957127492157 -- Fitting:127.68809150173875 -- SR:0.7379593851890276
#
# Loop25/1000 Turbulence: 932.2764218129471 -- Residual:187.9165971419639 -- Fitting:127.44698335105991 -- SR:0.745564830788548
#
# Loop26/1000 Turbulence: 932.8596402420269 -- Residual:185.1963890849693 -- Fitting:126.99483779251713 -- SR:0.7518832284853069
#
# Loop27/1000 Turbulence: 933.4676320390203 -- Residual:182.64856866451876 -- Fitting:126.5024253369279 -- SR:0.7577651946510642
#
# Loop28/1000 Turbulence: 934.1225295800947 -- Residual:180.34311984443232 -- Fitting:126.0656304895942 -- SR:0.7630562697807256
#
# Loop29/1000 Turbulence: 934.7977758938504 -- Residual:178.6037865924688 -- Fitting:125.73880614655445 -- SR:0.7670276601075467
#
# Loop30/1000 Turbulence: 935.4622431928547 -- Residual:177.8887751750923 -- Fitting:125.60449550775897 -- SR:0.7686550066661685
#
# Loop31/1000 Turbulence: 936.1108023117383 -- Residual:177.52300457053116 -- Fitting:125.5563551788715 -- SR:0.7694862957746137
#
# Loop32/1000 Turbulence: 936.755618584077 -- Residual:177.4927995306777 -- Fitting:125.77933992428056 -- SR:0.7695549065973045
#
# Loop33/1000 Turbulence: 937.3335755384809 -- Residual:177.503655954337 -- Fitting:125.9750217524721 -- SR:0.7695302468439222
#
# Loop34/1000 Turbulence: 937.8998263037755 -- Residual:178.0475444297874 -- Fitting:126.42501454127245 -- SR:0.7682939183636158
#
# Loop35/1000 Turbulence: 938.3890144976374 -- Residual:178.6869716561357 -- Fitting:126.54727330171775 -- SR:0.7668381336797863
#
# Loop36/1000 Turbulence: 938.8552495299134 -- Residual:179.62818098462546 -- Fitting:126.69095372027162 -- SR:0.7646908391874595
#
# Loop37/1000 Turbulence: 939.2652615943222 -- Residual:180.4271475318358 -- Fitting:126.34562921163155 -- SR:0.7628639604933732
#
# Loop38/1000 Turbulence: 939.6803350526297 -- Residual:181.63700953001856 -- Fitting:126.12581533308476 -- SR:0.7600904929691752
#
# Loop39/1000 Turbulence: 940.0422469774073 -- Residual:182.12950146843343 -- Fitting:125.50282919209995 -- SR:0.7589591116676413
#
# Loop40/1000 Turbulence: 940.4125716982516 -- Residual:181.6249867137195 -- Fitting:125.20636626175015 -- SR:0.7601180952289474
#
# Loop41/1000 Turbulence: 940.7081657946803 -- Residual:179.4233205887828 -- Fitting:124.77646797400891 -- SR:0.7651586591289686
#
# Loop42/1000 Turbulence: 940.9557558048043 -- Residual:176.54001145018253 -- Fitting:124.83079109182482 -- SR:0.7717163003403692
#
# Loop43/1000 Turbulence: 941.0895583378839 -- Residual:173.4440045539103 -- Fitting:124.79015520646767 -- SR:0.7787004077941865
#
# Loop44/1000 Turbulence: 941.2211055810693 -- Residual:171.4260607766287 -- Fitting:125.20602121738898 -- SR:0.7832193558616803
#
# Loop45/1000 Turbulence: 941.2707572880989 -- Residual:170.93425338070574 -- Fitting:125.52221583609338 -- SR:0.7843166200323441
#
# Loop46/1000 Turbulence: 941.3073759391967 -- Residual:172.09846585484308 -- Fitting:126.22874067267762 -- SR:0.7817165584476744
#
# Loop47/1000 Turbulence: 941.2657979908114 -- Residual:173.75244921439548 -- Fitting:126.61550395785171 -- SR:0.7780073413435915
#
# Loop48/1000 Turbulence: 941.2249909396595 -- Residual:176.09896358006776 -- Fitting:127.28192087496667 -- SR:0.7727149193563203
#
# Loop49/1000 Turbulence: 941.0819851977581 -- Residual:177.70184158404456 -- Fitting:127.5596318528439 -- SR:0.7690799533054169
#
# Loop50/1000 Turbulence: 940.9131656642178 -- Residual:178.86517940056913 -- Fitting:127.87495238594268 -- SR:0.7664319711018083
#
# Loop51/1000 Turbulence: 940.6394051729673 -- Residual:179.04326862375663 -- Fitting:127.67608057131233 -- SR:0.7660258894185442
#
# Loop52/1000 Turbulence: 940.3084772911734 -- Residual:178.75143039262673 -- Fitting:127.55692496314325 -- SR:0.7666912443065804
#
# Loop53/1000 Turbulence: 939.8874444021825 -- Residual:177.40340438883726 -- Fitting:127.1352518124867 -- SR:0.7697579353013146
#
# Loop54/1000 Turbulence: 939.4760897060303 -- Residual:175.77638973002803 -- Fitting:126.99602299067912 -- SR:0.7734445239027251
#
# Loop55/1000 Turbulence: 939.0369007185884 -- Residual:174.13442822029137 -- Fitting:126.7254861174924 -- SR:0.7771481960631427
#
# Loop56/1000 Turbulence: 938.6210871100055 -- Residual:172.86783335857822 -- Fitting:126.76838427007083 -- SR:0.7799933969130101
#
# Loop57/1000 Turbulence: 938.2147844002121 -- Residual:171.98824426899196 -- Fitting:126.83446356186919 -- SR:0.7819631042535551
#
# Loop58/1000 Turbulence: 937.8415296092656 -- Residual:171.37591637504553 -- Fitting:127.06213965853586 -- SR:0.7833313062218838
#
# Loop59/1000 Turbulence: 937.4596692151497 -- Residual:170.8811869331284 -- Fitting:126.99562759421366 -- SR:0.7844349190496087
#
# Loop60/1000 Turbulence: 937.1018422387425 -- Residual:171.0577263622406 -- Fitting:126.91030822716839 -- SR:0.7840412933432558
#
# Loop61/1000 Turbulence: 936.7690238865899 -- Residual:171.6922456720482 -- Fitting:126.54434958290099 -- SR:0.7826248021514369
#
# Loop62/1000 Turbulence: 936.5153092889527 -- Residual:173.15456974995357 -- Fitting:126.33236008990983 -- SR:0.7793501997645097
#
# Loop63/1000 Turbulence: 936.2988500962109 -- Residual:173.75967533698133 -- Fitting:125.8702177667992 -- SR:0.7779910970913854
#
# Loop64/1000 Turbulence: 936.1937773602481 -- Residual:173.95649627710281 -- Fitting:125.68471486130052 -- SR:0.7775485163260726
#
# Loop65/1000 Turbulence: 936.1613642799509 -- Residual:173.5098995033125 -- Fitting:125.27795014731007 -- SR:0.7785523953235065
#
# Loop66/1000 Turbulence: 936.2720717239899 -- Residual:173.34346573084395 -- Fitting:125.19979949401831 -- SR:0.7789261827805177
#
# Loop67/1000 Turbulence: 936.4939260705971 -- Residual:173.14673405269852 -- Fitting:125.03503662836165 -- SR:0.779367783640052
#
# Loop68/1000 Turbulence: 936.8824097120112 -- Residual:173.27312193239695 -- Fitting:125.26324409484373 -- SR:0.7790841113713067
#
# Loop69/1000 Turbulence: 937.3550732590207 -- Residual:173.67889994432457 -- Fitting:125.29321612079386 -- SR:0.7781726602328285
#
# Loop70/1000 Turbulence: 937.9678640139338 -- Residual:174.69883233057706 -- Fitting:125.61373830528132 -- SR:0.7758770315820028
#
# Loop71/1000 Turbulence: 938.6411420622986 -- Residual:175.87718621431398 -- Fitting:125.8218303306929 -- SR:0.7732166099714906
#
# Loop72/1000 Turbulence: 939.390673323031 -- Residual:176.926471797342 -- Fitting:126.27830004643394 -- SR:0.7708402894244599
#
# Loop73/1000 Turbulence: 940.142257831933 -- Residual:177.37031402785257 -- Fitting:126.5615259187803 -- SR:0.7698330757167413
#
# Loop74/1000 Turbulence: 940.9107560134802 -- Residual:177.2441904615857 -- Fitting:127.03431584527294 -- SR:0.7701194113085496
#
# Loop75/1000 Turbulence: 941.651302811185 -- Residual:176.98991954218292 -- Fitting:127.44355243012161 -- SR:0.7706963810700654
#
# Loop76/1000 Turbulence: 942.3566508156321 -- Residual:176.94637110098998 -- Fitting:127.96891857781534 -- SR:0.7707951576839832
#
# Loop77/1000 Turbulence: 942.9780981772232 -- Residual:177.5085541775751 -- Fitting:128.24304082976775 -- SR:0.7695191205713305
#
# Loop78/1000 Turbulence: 943.5583416367402 -- Residual:178.78930648082218 -- Fitting:128.52815403653634 -- SR:0.7666049202224307
#
# Loop79/1000 Turbulence: 944.0660879293911 -- Residual:180.75643296821357 -- Fitting:128.63468892721002 -- SR:0.7621099486270466
#
# Loop80/1000 Turbulence: 944.4977091746894 -- Residual:182.6999760483986 -- Fitting:128.72303471022937 -- SR:0.7576468689994384
#
# Loop81/1000 Turbulence: 944.8202580766947 -- Residual:183.67568742235906 -- Fitting:128.69791680799088 -- SR:0.7553982554316381
#
# Loop82/1000 Turbulence: 945.08855230299 -- Residual:183.87124164025718 -- Fitting:128.51958497877885 -- SR:0.7549469490498935
#
# Loop83/1000 Turbulence: 945.3975116658909 -- Residual:183.81629228996962 -- Fitting:128.24329872069973 -- SR:0.755073784208843
#
# Loop84/1000 Turbulence: 945.7257895506036 -- Residual:182.85329651890126 -- Fitting:127.81143083685355 -- SR:0.7572938795380755
#
# Loop85/1000 Turbulence: 946.0980705023305 -- Residual:181.95828647625004 -- Fitting:127.55181888744053 -- SR:0.7593525929820691
#
# Loop86/1000 Turbulence: 946.4804157658655 -- Residual:181.05082610402977 -- Fitting:127.1553752488196 -- SR:0.7614353032234562
#
# Loop87/1000 Turbulence: 946.9465008181724 -- Residual:180.48020375730616 -- Fitting:126.860390631905 -- SR:0.7627425126294142
#
# Loop88/1000 Turbulence: 947.4255626869223 -- Residual:179.7684750750619 -- Fitting:126.35650212389412 -- SR:0.7643703203634336
#
# Loop89/1000 Turbulence: 948.0233928303796 -- Residual:179.96637152351954 -- Fitting:126.04926436539606 -- SR:0.763918005277822
#
# Loop90/1000 Turbulence: 948.7186614172031 -- Residual:180.63435006856875 -- Fitting:125.57719154960343 -- SR:0.7623895726476195
#
# Loop91/1000 Turbulence: 949.5101429628139 -- Residual:181.98252293010185 -- Fitting:125.28216132498046 -- SR:0.759296903566017
#
# Loop92/1000 Turbulence: 950.3495931662617 -- Residual:183.71042467054843 -- Fitting:124.90287832168143 -- SR:0.7553181030634165
#
# Loop93/1000 Turbulence: 951.2985144798376 -- Residual:185.87096916574274 -- Fitting:124.8685516597107 -- SR:0.7503199726002722
#
# Loop94/1000 Turbulence: 952.3518391437831 -- Residual:187.7244855343968 -- Fitting:124.7982149784043 -- SR:0.7460123252666491
#
# Loop95/1000 Turbulence: 953.5386252913368 -- Residual:188.79420241107516 -- Fitting:124.96063026249726 -- SR:0.7435181919465518
#
# Loop96/1000 Turbulence: 954.8018941308103 -- Residual:188.80133457937262 -- Fitting:125.09358525490848 -- SR:0.7435015432419361
#
# Loop97/1000 Turbulence: 956.1876717549235 -- Residual:189.20081366946127 -- Fitting:125.68183169352828 -- SR:0.7425686265575936
#
# Loop98/1000 Turbulence: 957.653153712795 -- Residual:190.24659762088487 -- Fitting:126.2541067399824 -- SR:0.7401226112266006
#
# Loop99/1000 Turbulence: 959.2765178637986 -- Residual:191.9855831949869 -- Fitting:127.36141236397324 -- SR:0.7360434336273042
#
# Loop100/1000 Turbulence: 960.9988095349526 -- Residual:194.69513383341538 -- Fitting:128.4263443736731 -- SR:0.7296592085192528
#
# Loop101/1000 Turbulence: 962.8807410297512 -- Residual:198.602917022687 -- Fitting:129.8477776511464 -- SR:0.7203942042316792
#
# Loop102/1000 Turbulence: 964.7671737080932 -- Residual:202.27431001822546 -- Fitting:130.78527483483444 -- SR:0.7116322062432741
#
# Loop103/1000 Turbulence: 966.7259930919336 -- Residual:205.83140259815318 -- Fitting:131.8444468415298 -- SR:0.7030943203280209
#
# Loop104/1000 Turbulence: 968.6342170749981 -- Residual:208.07860041496667 -- Fitting:132.25943689493673 -- SR:0.6976777073867064
#
# Loop105/1000 Turbulence: 970.5598952821309 -- Residual:209.04967885915036 -- Fitting:132.6443199478112 -- SR:0.6953318968725487
#
# Loop106/1000 Turbulence: 972.3887309381781 -- Residual:208.15446819109835 -- Fitting:132.31196018562287 -- SR:0.6974945446840769
#
# Loop107/1000 Turbulence: 974.2276635762837 -- Residual:207.2284978975027 -- Fitting:132.13524792733418 -- SR:0.6997287674393718
#
# Loop108/1000 Turbulence: 975.9403225819999 -- Residual:206.64853461607407 -- Fitting:131.49949403307673 -- SR:0.7011266808941196
#
# Loop109/1000 Turbulence: 977.5937484208497 -- Residual:206.60980087343134 -- Fitting:131.27950742704778 -- SR:0.7012200024039161
#
# Loop110/1000 Turbulence: 979.1417645970747 -- Residual:206.90205701329194 -- Fitting:130.83548119079526 -- SR:0.7005157424338732
#
# Loop111/1000 Turbulence: 980.7058616410701 -- Residual:209.00411323618917 -- Fitting:131.00820931567327 -- SR:0.6954420359162125
#
# Loop112/1000 Turbulence: 982.1445678874101 -- Residual:211.44835334944875 -- Fitting:130.89474971934686 -- SR:0.689524882768516
#
# Loop113/1000 Turbulence: 983.5885327456115 -- Residual:214.6474886481963 -- Fitting:131.3058523931228 -- SR:0.681753893845753
#
# Loop114/1000 Turbulence: 984.9389518172175 -- Residual:218.32653124725684 -- Fitting:131.4489910978656 -- SR:0.6727838062683404
#
# Loop115/1000 Turbulence: 986.3791814107218 -- Residual:222.71637747986875 -- Fitting:132.18308945536535 -- SR:0.6620399551255326
#
# Loop116/1000 Turbulence: 987.7743980604762 -- Residual:225.96013543776098 -- Fitting:132.57020932602495 -- SR:0.6540767817855394
#
# Loop117/1000 Turbulence: 989.2124644778046 -- Residual:229.98151962837105 -- Fitting:133.22951172361994 -- SR:0.6441809427548495
#
# Loop118/1000 Turbulence: 990.6604579463284 -- Residual:235.0512575024513 -- Fitting:133.38014610416565 -- SR:0.6316762646975861
#
# Loop119/1000 Turbulence: 992.1981181687848 -- Residual:240.47954960817282 -- Fitting:133.53895261397457 -- SR:0.6182631560608751
#
# Loop120/1000 Turbulence: 993.7425621166668 -- Residual:244.02574298874723 -- Fitting:133.15273537618629 -- SR:0.6094935286485413
#
# Loop121/1000 Turbulence: 995.4056872535517 -- Residual:245.3465743789211 -- Fitting:132.76373966587414 -- SR:0.606226637709764
#
# Loop122/1000 Turbulence: 997.1289509622283 -- Residual:243.95040520859388 -- Fitting:131.98430551588868 -- SR:0.6096798626742064
#
# Loop123/1000 Turbulence: 998.9346740155448 -- Residual:239.78381886350786 -- Fitting:131.07245851941855 -- SR:0.619983212598715
#
# Loop124/1000 Turbulence: 1000.8336262692144 -- Residual:235.16342358752811 -- Fitting:130.01389536676925 -- SR:0.6313993140669316
#
# Loop125/1000 Turbulence: 1002.8255041128688 -- Residual:229.73216675944556 -- Fitting:129.14123343420775 -- SR:0.6447952164744628
#
# Loop126/1000 Turbulence: 1004.857096517425 -- Residual:224.46334510540456 -- Fitting:128.47694636935162 -- SR:0.657753614104729
#
# Loop127/1000 Turbulence: 1006.9614067211149 -- Residual:220.03436707014467 -- Fitting:128.0799653528666 -- SR:0.668608890259064
#
# Loop128/1000 Turbulence: 1009.1235566104066 -- Residual:216.5471516430481 -- Fitting:127.99126732783832 -- SR:0.6771264120060284
#
# Loop129/1000 Turbulence: 1011.3102800399503 -- Residual:214.40406502843186 -- Fitting:128.2643184869533 -- SR:0.6823461828659225
#
# Loop130/1000 Turbulence: 1013.5142003343855 -- Residual:213.47746238471598 -- Fitting:128.82419906925608 -- SR:0.684599296796973
#
# Loop131/1000 Turbulence: 1015.7218681975272 -- Residual:213.09323330607313 -- Fitting:129.46099997896732 -- SR:0.6855328926836569
#
# Loop132/1000 Turbulence: 1017.9447038108184 -- Residual:212.93572274754538 -- Fitting:130.19305425039553 -- SR:0.6859154914152109
#
# Loop133/1000 Turbulence: 1020.1779333852784 -- Residual:212.64475028550532 -- Fitting:130.8820950040679 -- SR:0.6866220904971029
#
# Loop134/1000 Turbulence: 1022.5108699753287 -- Residual:212.1866826557887 -- Fitting:131.6549495199014 -- SR:0.6877339776058204
#
# Loop135/1000 Turbulence: 1024.9516429573262 -- Residual:211.07597471030616 -- Fitting:132.21782732126405 -- SR:0.6904275253299516
#
# Loop136/1000 Turbulence: 1027.5128435855545 -- Residual:209.64643354508155 -- Fitting:132.8086609423218 -- SR:0.6938888476321373
#
# Loop137/1000 Turbulence: 1030.1146947619736 -- Residual:208.38652586924098 -- Fitting:133.033243470674 -- SR:0.6969341870775694
#
# Loop138/1000 Turbulence: 1032.75416642182 -- Residual:207.39096659181683 -- Fitting:133.1170037548251 -- SR:0.6993369599224906
#
# Loop139/1000 Turbulence: 1035.3526102623312 -- Residual:206.955387411272 -- Fitting:132.8083354002878 -- SR:0.7003871992884266
#
# Loop140/1000 Turbulence: 1037.9592769892677 -- Residual:207.112256475226 -- Fitting:132.51072196883214 -- SR:0.70000903997043
#
# Loop141/1000 Turbulence: 1040.5510789985333 -- Residual:206.91855313116375 -- Fitting:131.93140206172288 -- SR:0.7004759825855983
#
# Loop142/1000 Turbulence: 1043.172401962395 -- Residual:206.7769595873572 -- Fitting:131.46158914551518 -- SR:0.7008172293575562
#
# Loop143/1000 Turbulence: 1045.745707081503 -- Residual:206.3107325961139 -- Fitting:130.91379148146143 -- SR:0.7019403786518656
#
# Loop144/1000 Turbulence: 1048.2707774061487 -- Residual:206.46971771419385 -- Fitting:130.7343556165235 -- SR:0.70155746344564
#
# Loop145/1000 Turbulence: 1050.7471839773875 -- Residual:206.2618235333498 -- Fitting:130.58273116013893 -- SR:0.7020581586684916
#
# Loop146/1000 Turbulence: 1053.246468590945 -- Residual:206.05532224356054 -- Fitting:130.78852834586291 -- SR:0.7025553531133948
#
# Loop147/1000 Turbulence: 1055.7451347564731 -- Residual:205.3191015180928 -- Fitting:130.90016615076746 -- SR:0.7043267590058958
#
# Loop148/1000 Turbulence: 1058.3144421999662 -- Residual:204.92313815318755 -- Fitting:131.31915044718886 -- SR:0.7052786959173987
#
# Loop149/1000 Turbulence: 1060.8637837563615 -- Residual:204.29298800660516 -- Fitting:131.38942709758848 -- SR:0.7067924958742448
#
# Loop150/1000 Turbulence: 1063.5252694953024 -- Residual:203.55143510081516 -- Fitting:131.67824019010968 -- SR:0.7085720862342656
#
# Loop151/1000 Turbulence: 1066.2055169325863 -- Residual:202.25393274190813 -- Fitting:131.42724910316554 -- SR:0.7116809827548078
#
# Loop152/1000 Turbulence: 1068.9649971982178 -- Residual:200.86261528797357 -- Fitting:131.40289858790177 -- SR:0.715007582375415
#
# Loop153/1000 Turbulence: 1071.6647109333758 -- Residual:199.0887957448097 -- Fitting:130.85452641761893 -- SR:0.7192377163763739
#
# Loop154/1000 Turbulence: 1074.3671481883919 -- Residual:197.66788799647233 -- Fitting:130.64674212320864 -- SR:0.722617011528649
#
# Loop155/1000 Turbulence: 1076.9336646135716 -- Residual:195.76258166431728 -- Fitting:130.0740539073428 -- SR:0.727134950727438
#
# Loop156/1000 Turbulence: 1079.4459884442576 -- Residual:194.60647945326892 -- Fitting:129.88320175434527 -- SR:0.7298686265448121
#
# Loop157/1000 Turbulence: 1081.8550276275748 -- Residual:193.99328167348867 -- Fitting:129.57970676021068 -- SR:0.731316142562405
#
# Loop158/1000 Turbulence: 1084.275623380659 -- Residual:194.40177499929464 -- Fitting:129.95067516767762 -- SR:0.730352041258389
#
# Loop159/1000 Turbulence: 1086.611119939538 -- Residual:195.2325896688994 -- Fitting:130.27231355432332 -- SR:0.7283888862331439
#
# Loop160/1000 Turbulence: 1088.8753345641069 -- Residual:196.20214219516217 -- Fitting:130.8836361697743 -- SR:0.7260940365336186
#
# Loop161/1000 Turbulence: 1090.9972872376836 -- Residual:196.81142688234453 -- Fitting:131.1413821867721 -- SR:0.7246498154386829
#
# Loop162/1000 Turbulence: 1093.0433835151152 -- Residual:197.13235159883757 -- Fitting:131.66358274284377 -- SR:0.7238884684563962
#
# Loop163/1000 Turbulence: 1094.9544894269945 -- Residual:196.9885639205968 -- Fitting:131.94926705824068 -- SR:0.7242296381224778
#
# Loop164/1000 Turbulence: 1096.731219927043 -- Residual:196.8290311375988 -- Fitting:132.41600531900113 -- SR:0.7246080633375337
#
# Loop165/1000 Turbulence: 1098.2841142548136 -- Residual:196.70995681779596 -- Fitting:132.57692937956966 -- SR:0.724890446580889
#
# Loop166/1000 Turbulence: 1099.6863463647387 -- Residual:197.38568152913936 -- Fitting:132.90958984386342 -- SR:0.7232871703147358
#
# Loop167/1000 Turbulence: 1100.9227738773197 -- Residual:197.88461890156012 -- Fitting:132.9513555870439 -- SR:0.7221021106069857
#
# Loop168/1000 Turbulence: 1102.0504210090824 -- Residual:198.87861678656415 -- Fitting:133.07495856028865 -- SR:0.7197381027857476
#
# Loop169/1000 Turbulence: 1103.0524519747457 -- Residual:199.48797869731578 -- Fitting:132.97069375033684 -- SR:0.7182868609920872
#
# Loop170/1000 Turbulence: 1103.9942109093902 -- Residual:199.9773169405202 -- Fitting:132.91774390442043 -- SR:0.717120377678849
#
# Loop171/1000 Turbulence: 1104.7916191695654 -- Residual:200.65713963650535 -- Fitting:132.56635097428043 -- SR:0.7154982327952497
#
# Loop172/1000 Turbulence: 1105.4964806916466 -- Residual:201.17780392201277 -- Fitting:132.22699596278832 -- SR:0.7142546301566005
#
# Loop173/1000 Turbulence: 1106.095492692428 -- Residual:201.48208556670264 -- Fitting:131.82163393764313 -- SR:0.7135273675304736
#
# Loop174/1000 Turbulence: 1106.6329185335185 -- Residual:201.7556662829483 -- Fitting:131.49531778764916 -- SR:0.7128731782651541
#
# Loop175/1000 Turbulence: 1107.0711120049407 -- Residual:201.5589957440893 -- Fitting:131.11384380387517 -- SR:0.71334348813219
#
# Loop176/1000 Turbulence: 1107.4478992749043 -- Residual:201.71457092611024 -- Fitting:131.02262531614232 -- SR:0.7129714642848006
#
# Loop177/1000 Turbulence: 1107.7506010672723 -- Residual:201.88399615773957 -- Fitting:130.9465781574399 -- SR:0.712566215544382
#
# Loop178/1000 Turbulence: 1107.9643250880047 -- Residual:202.0442146992172 -- Fitting:131.05092177781592 -- SR:0.7121828874747672
#
# Loop179/1000 Turbulence: 1108.0721171856226 -- Residual:201.96953984806257 -- Fitting:131.08943224561537 -- SR:0.7123615616555335
#
# Loop180/1000 Turbulence: 1108.2132756739943 -- Residual:202.4515216414829 -- Fitting:131.40716798729161 -- SR:0.7112079536454665
#
# Loop181/1000 Turbulence: 1108.323399366314 -- Residual:202.74116642436837 -- Fitting:131.58820650795198 -- SR:0.7105142766210553
#
# Loop182/1000 Turbulence: 1108.4172653933572 -- Residual:203.06640339250438 -- Fitting:131.91451772238293 -- SR:0.7097349852684794
#
# Loop183/1000 Turbulence: 1108.4425660626584 -- Residual:202.83731838681845 -- Fitting:132.05356164818224 -- SR:0.7102839305875788
#
# Loop184/1000 Turbulence: 1108.4433965177998 -- Residual:202.62076726173078 -- Fitting:132.271364180421 -- SR:0.710802661600071
#
# Loop185/1000 Turbulence: 1108.3529664292457 -- Residual:201.42921202559148 -- Fitting:132.3588487314123 -- SR:0.713653766117183
#
# Loop186/1000 Turbulence: 1108.2326526868242 -- Residual:200.3019982480373 -- Fitting:132.51852067796466 -- SR:0.7163458746052866
#
# Loop187/1000 Turbulence: 1108.065040701713 -- Residual:199.01951427534252 -- Fitting:132.76096770923914 -- SR:0.7194026791168866
#
# Loop188/1000 Turbulence: 1107.8654343128833 -- Residual:197.6379157996244 -- Fitting:133.1094288175548 -- SR:0.722688202778334
#
# Loop189/1000 Turbulence: 1107.6601017993692 -- Residual:196.67599882843663 -- Fitting:133.42710413977588 -- SR:0.7249709663629269
#
# Loop190/1000 Turbulence: 1107.446801416012 -- Residual:196.25293815130425 -- Fitting:133.6361358500242 -- SR:0.7259736934186776
#
# Loop191/1000 Turbulence: 1107.2606658719958 -- Residual:197.1187603174497 -- Fitting:133.81591968422669 -- SR:0.7239207207006454
#
# Loop192/1000 Turbulence: 1107.082025563663 -- Residual:198.57719310372815 -- Fitting:133.7878463234172 -- SR:0.7204554052372634
#
# Loop193/1000 Turbulence: 1106.9256578291706 -- Residual:199.92886250537546 -- Fitting:133.6332850510962 -- SR:0.717235926089499
#
# Loop194/1000 Turbulence: 1106.7655929675086 -- Residual:200.36348941015785 -- Fitting:133.29183600883675 -- SR:0.7161991448497568
#
# Loop195/1000 Turbulence: 1106.659656723296 -- Residual:199.79510427386688 -- Fitting:133.01979364150853 -- SR:0.7175548481457786
#
# Loop196/1000 Turbulence: 1106.5324203978976 -- Residual:198.51439833019668 -- Fitting:132.51068017434216 -- SR:0.7206047918194579
#
# Loop197/1000 Turbulence: 1106.4280640619575 -- Residual:197.55790151775847 -- Fitting:132.0383134238299 -- SR:0.7228782375995215
#
# Loop198/1000 Turbulence: 1106.274994477499 -- Residual:197.27598297517707 -- Fitting:131.36084364849464 -- SR:0.7235475817514222
#
# Loop199/1000 Turbulence: 1106.1231621606998 -- Residual:198.07493380898384 -- Fitting:130.94703843109434 -- SR:0.7216498055191639
#
# Loop200/1000 Turbulence: 1105.8818754192268 -- Residual:199.610391716508 -- Fitting:130.27392631294182 -- SR:0.7179951434419376
#
# Loop201/1000 Turbulence: 1105.6347605645785 -- Residual:202.242702498355 -- Fitting:129.96204703688815 -- SR:0.7117078636004631
#
# Loop202/1000 Turbulence: 1105.2958797154513 -- Residual:205.31378470151492 -- Fitting:129.4107879400783 -- SR:0.7043395448325573
#
# Loop203/1000 Turbulence: 1104.9084964319275 -- Residual:208.89916332698445 -- Fitting:129.19297728747495 -- SR:0.6956956908112343
#
# Loop204/1000 Turbulence: 1104.385959265816 -- Residual:212.54472353724415 -- Fitting:128.63915768254918 -- SR:0.686864940713159
#
# Loop205/1000 Turbulence: 1103.8277941275146 -- Residual:216.22956361685672 -- Fitting:128.4191941841221 -- SR:0.6779006798413818
#
# Loop206/1000 Turbulence: 1103.1938524163452 -- Residual:218.6661387268683 -- Fitting:127.95645898623951 -- SR:0.6719541383749736
#
# Loop207/1000 Turbulence: 1102.579844525575 -- Residual:220.29096676989212 -- Fitting:127.90580486273328 -- SR:0.6679810585353215
#
# Loop208/1000 Turbulence: 1101.913592732133 -- Residual:220.7959588185905 -- Fitting:127.75525792581898 -- SR:0.666745065447109
#
# Loop209/1000 Turbulence: 1101.259917399724 -- Residual:221.53718560661056 -- Fitting:128.16698490544354 -- SR:0.6649299099331087
#
# Loop210/1000 Turbulence: 1100.5122314058099 -- Residual:222.59959700544505 -- Fitting:128.46177523545194 -- SR:0.662326281849326
#
# Loop211/1000 Turbulence: 1099.713622874846 -- Residual:224.78199206829902 -- Fitting:129.03235175571533 -- SR:0.6569711877927978
#
# Loop212/1000 Turbulence: 1098.848313722702 -- Residual:226.93532193828148 -- Fitting:129.31983483536433 -- SR:0.6516792604422723
#
# Loop213/1000 Turbulence: 1097.9967946872541 -- Residual:227.98525071821607 -- Fitting:129.93396367266348 -- SR:0.6490963312159811
#
# Loop214/1000 Turbulence: 1097.1022124081485 -- Residual:227.38436199200365 -- Fitting:130.1791932245255 -- SR:0.6505747812838292
#
# Loop215/1000 Turbulence: 1096.2286176606228 -- Residual:226.08108149560846 -- Fitting:130.63053662683893 -- SR:0.6537795159124774
#
# Loop216/1000 Turbulence: 1095.2884188071625 -- Residual:224.12051781190385 -- Fitting:130.59067457273505 -- SR:0.6585952131784886
#
# Loop217/1000 Turbulence: 1094.4293894982263 -- Residual:222.1485387787467 -- Fitting:130.80578725953097 -- SR:0.6634319537127564
#
# Loop218/1000 Turbulence: 1093.6100564193823 -- Residual:219.85260683018396 -- Fitting:130.47215254902426 -- SR:0.6690535233466688
#
# Loop219/1000 Turbulence: 1092.930869043615 -- Residual:218.07260936790652 -- Fitting:130.52693613010575 -- SR:0.6734039679123688
#
# Loop220/1000 Turbulence: 1092.263286870946 -- Residual:216.51692060309233 -- Fitting:130.24995583340086 -- SR:0.6772001249762195
#
# Loop221/1000 Turbulence: 1091.6717603765926 -- Residual:215.25047954523444 -- Fitting:130.41398844809316 -- SR:0.6802860457841947
#
# Loop222/1000 Turbulence: 1091.0850716445225 -- Residual:213.4330257673084 -- Fitting:130.20970108973614 -- SR:0.6847072893463019
#
# Loop223/1000 Turbulence: 1090.5993210833847 -- Residual:211.2377162400013 -- Fitting:130.41698058693865 -- SR:0.6900355156782929
#
# Loop224/1000 Turbulence: 1090.1304340387192 -- Residual:209.14088134938658 -- Fitting:130.32192169466398 -- SR:0.6951114268786687
#
# Loop225/1000 Turbulence: 1089.794750913258 -- Residual:207.7833935758353 -- Fitting:130.60135804892315 -- SR:0.6983902280139642
#
# Loop226/1000 Turbulence: 1089.5143924889528 -- Residual:206.08327084226116 -- Fitting:130.58542285643463 -- SR:0.7024880696484335
#
# Loop227/1000 Turbulence: 1089.391087601354 -- Residual:203.58952336625657 -- Fitting:130.90324464721985 -- SR:0.7084807301855648
#
# Loop228/1000 Turbulence: 1089.3428317488701 -- Residual:199.91610108250106 -- Fitting:130.88360081256226 -- SR:0.7172663564609933
#
# Loop229/1000 Turbulence: 1089.398838457869 -- Residual:196.19471816659797 -- Fitting:130.93535327627973 -- SR:0.7261116242139694
#
# Loop230/1000 Turbulence: 1089.5121307997981 -- Residual:192.67847053129827 -- Fitting:130.5474594423493 -- SR:0.734414093266958
#
# Loop231/1000 Turbulence: 1089.71058272233 -- Residual:190.32834976152427 -- Fitting:130.3213752483113 -- SR:0.7399311714826952
#
# Loop232/1000 Turbulence: 1089.9004297305773 -- Residual:188.86601925183365 -- Fitting:129.76606396287414 -- SR:0.7433505373570203
#
# Loop233/1000 Turbulence: 1090.1185697604526 -- Residual:188.2286790464001 -- Fitting:129.30812534428404 -- SR:0.7448374815953589
#
# Loop234/1000 Turbulence: 1090.3101282080245 -- Residual:187.68740808255671 -- Fitting:128.7099432546233 -- SR:0.7460986696948332
#
# Loop235/1000 Turbulence: 1090.5129994056947 -- Residual:187.2775259515594 -- Fitting:128.29646817256787 -- SR:0.7470527143511527
#
# Loop236/1000 Turbulence: 1090.7437295933905 -- Residual:187.5398105307633 -- Fitting:128.0045724767839 -- SR:0.7464423186497747
#
# Loop237/1000 Turbulence: 1091.052233729226 -- Residual:188.56368712755236 -- Fitting:127.73011536473464 -- SR:0.7440561483724283
#
# Loop238/1000 Turbulence: 1091.490134193288 -- Residual:190.31844252317936 -- Fitting:127.5389099463714 -- SR:0.7399543730965282
#
# Loop239/1000 Turbulence: 1092.0422705689593 -- Residual:192.11634399464714 -- Fitting:127.19030567840572 -- SR:0.7357361198055761
#
# Loop240/1000 Turbulence: 1092.7452422829058 -- Residual:194.1413754334177 -- Fitting:126.917487885758 -- SR:0.7309667080135958
#
# Loop241/1000 Turbulence: 1093.494468177609 -- Residual:196.2110249801323 -- Fitting:126.45279257579578 -- SR:0.7260729927138735
#
# Loop242/1000 Turbulence: 1094.2995602535802 -- Residual:198.36676035732114 -- Fitting:126.10418266973002 -- SR:0.72095595322208
#
# Loop243/1000 Turbulence: 1095.0953659381844 -- Residual:200.17598933369672 -- Fitting:125.50526077501341 -- SR:0.7166465092842716
#
# Loop244/1000 Turbulence: 1095.945215684963 -- Residual:202.8100735249953 -- Fitting:125.16605093088936 -- SR:0.7103492031282534
#
# Loop245/1000 Turbulence: 1096.7884397639475 -- Residual:206.04183622528777 -- Fitting:124.85456013776336 -- SR:0.7025878183985222
#
# Loop246/1000 Turbulence: 1097.6953317380708 -- Residual:210.30840965094393 -- Fitting:125.03235094339303 -- SR:0.6922867895517092
#
# Loop247/1000 Turbulence: 1098.6088753405866 -- Residual:214.94297838217753 -- Fitting:125.16905069095857 -- SR:0.6810347086061235
#
# Loop248/1000 Turbulence: 1099.621003968054 -- Residual:219.48146584507924 -- Fitting:125.70121436324455 -- SR:0.6699612067009868
#
# Loop249/1000 Turbulence: 1100.6779828780284 -- Residual:222.39327067956324 -- Fitting:126.1346086903115 -- SR:0.6628320957271989
#
# Loop250/1000 Turbulence: 1101.7900122382523 -- Residual:224.11544453410585 -- Fitting:126.79902245294721 -- SR:0.658607665871818
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 KAO.param['print_display'] =True
#       2 KAO.param['nLoop']=1000
# ----> 4 AO_output_modal,L_psf,L_coro = close_loop(KAO)
#       5 SR_mode = AO_output_modal['SR']
#       6 res_mode = AO_output_modal['residual']
#
# File ~/keckAOSim/keckSim/simulations_codes/close_loop_coro.py:178, in close_loop(AO_sys, atm_seed)
#     175 OPD_fitting_2D, OPD_corr_2D, OPD_turb_2D = getFittingError(AO_sys.tel.OPD, proj, modes_proj, display=False)
#     176 fitting_rms[i] = np.std(OPD_fitting_2D[np.where(AO_sys.tel.pupil > 0)]) * 1e9
# --> 178 AO_sys.science * AO_sys.tel * AO_sys.opd_ncpa * AO_sys.science_detector
#     180 if i >= latency:
#     181     command = np.matmul(Rec, signalBuffer[:, i-latency])
#
# File ~/OOPAO/OOPAO/Telescope.py:613, in Telescope.__mul__(self, obj)
#     610 if self.optical_path[-1] != obj.tag:
#     611     self.optical_path.append([obj.tag, id(obj)])
# --> 613 self.computePSF(detector=obj)
#     614 obj.fov_arcsec = self.xPSF_arcsec[1] - self.xPSF_arcsec[0]
#     615 obj.fov_rad = self.xPSF_rad[1] - self.xPSF_rad[0]
#
# File ~/OOPAO/OOPAO/Telescope.py:315, in Telescope.computePSF(self, zeroPaddingFactor, detector, img_resolution)
#     311 self.yPSF_rad = [-(input_source[i_src].wavelength/self.D) * (n_pix/2/zeroPaddingFactor),
#     312                  (input_source[i_src].wavelength/self.D) * (n_pix/2/zeroPaddingFactor)]
#     314 # propagate the EM Field
# --> 315 self.PropagateField(amplitude=amp,
#     316                     phase=phase+self.delta_TT*factor,
#     317                     zeroPaddingFactor=zeroPaddingFactor,
#     318                     img_resolution=img_resolution)
#     320 # normalized PSF
#     321 self.PSF_norma = self.PSF/self.PSF.max()
#
# File ~/OOPAO/OOPAO/Telescope.py:388, in Telescope.PropagateField(self, amplitude, phase, zeroPaddingFactor, img_resolution)
#     385     self.phasor = xp.exp(-1j * xp.pi * (N + 1) / N * (xx + yy) * (1 - img_resolution % 2)).astype(self.precision_complex())
#     386     #                                                        ^--- this is to account odd/even number of pixels
#     387     # Propagate with Fourier shifting
# --> 388     EMF = xp.fft.fftshift(1 / N * xp.fft.fft2(xp.fft.ifftshift(supportPadded * self.phasor))).astype(self.precision_complex())
#     389     EMF = (1 / N * xp.fft.fft2((supportPadded * self.phasor))).astype(self.precision_complex())
#     391 # Again, this is to properly crop a PSF with the odd/even number of pixels
#
# File /opt/anaconda3/envs/oopao/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:1014, in fft2(a, s, axes, norm)
#     921 @array_function_dispatch(_fftn_dispatcher)
#     922 def fft2(a, s=None, axes=(-2, -1), norm=None):
#     923     """
#     924     Compute the 2-dimensional discrete Fourier Transform.
#     925
#    (...)
#    1012
#    1013     """
# -> 1014     return _raw_fftnd(a, s, axes, fft, norm)
#
# File /opt/anaconda3/envs/oopao/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:707, in _raw_fftnd(a, s, axes, function, norm)
#     705 itl.reverse()
#     706 for ii in itl:
# --> 707     a = function(a, n=s[ii], axis=axes[ii], norm=norm)
#     708 return a
#
# File /opt/anaconda3/envs/oopao/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:215, in fft(a, n, axis, norm)
#     213     n = a.shape[axis]
#     214 inv_norm = _get_forward_norm(n, norm)
# --> 215 output = _raw_fft(a, n, axis, False, True, inv_norm)
#     216 return output
#
# File /opt/anaconda3/envs/oopao/lib/python3.9/site-packages/numpy/fft/_pocketfft.py:73, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
# ---> 73     r = pfi.execute(a, is_real, is_forward, fct)
#      74     r = swapaxes(r, axis, -1)
#      75 return r
#
# KeyboardInterrupt:

# %%
f1 = "/Users/mayragutierrez/keckAOSim/keckSim/simulations_codes/MGDATA/L_current_coro_120nm_mag5_1757627126504995_27s_sum.fits"
f2 = "/Users/mayragutierrez/keckAOSim/keckSim/simulations_codes/MGDATA/L_current_psf_120nm_mag5_1757627126504995_27s_sum.fits"

d1 = fits.getdata(f1)
d2 = fits.getdata(f2)

fig, axs = plt.subplots(1, 2, figsize=(12,6))
psf=np.sum(L_psf, axis=0)
coro=np.sum(L_coro, axis=0)
im1 = axs[0].imshow(psf/np.max(psf), origin="lower", cmap="viridis")#, norm=plt.matplotlib.colors.LogNorm())
fig.colorbar(im1, ax=axs[0], fraction=0.046, pad=0.04)
axs[0].set_title("Coronagraphic PSF")

im2 = axs[1].imshow(coro/np.max(psf), origin="lower", cmap="viridis")#, norm=plt.matplotlib.colors.LogNorm())
fig.colorbar(im2, ax=axs[1], fraction=0.046, pad=0.04)
axs[1].set_title("Non-Coronagraphic PSF")

plt.tight_layout()
plt.show()

# %%
from astropy.io import fits

filename = "/Users/mayragutierrez/keckAOSim/keckSim/simulations_codes/MGDATA/L_current_coro_120nm_mag5_1757599077975165_27s_sum.fits"

hdul = fits.open(filename)
hdul.info()

for i, hdu in enumerate(hdul):
    print(f"HDU {i} data type: {type(hdu.data)} shape: {getattr(hdu.data, 'shape', None)}")
hdul.close()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Replace with your actual filename
strehl_file = "/Users/mayragutierrez/keckAOSim/keckSim/simulations_codes/MGDATA/strehl_K_current_120nm_mag5_1757627126504995.npy"

strehl = np.load(strehl_file)

plt.figure(figsize=(8,5))
plt.plot(strehl, color="royalblue")
plt.xlabel("Iteration")
plt.ylabel("Strehl ratio")
plt.title("AO Strehl evolution")
plt.grid(True)
plt.show()

print("Final Strehl:", strehl[-1])
print("Mean Strehl:", np.mean(strehl))

# %%
import numpy as np

strehl = np.load(strehl_file)

n_frames = len(strehl)
dt = 0.001  # seconds per frame from param['samplingTime']
t_exp = n_frames * dt

print(f"Frames: {n_frames}")
print(f"Total exposure time: {t_exp:.2f} s")
